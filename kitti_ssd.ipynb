# %% [markdown]
# <a href="https://colab.research.google.com/github/ye019/ssd_resnet50_kitti/blob/main/kitti_ssd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# !git clone https://github.com/qijiezhao/pytorch-ssd
# Out:
# Cloning into 'pytorch-ssd'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 121 (delta 25), reused 23 (delta 23), pack-reused 85
# Receiving objects: 100% (121/121), 3.84 MiB | 10.78 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %% [markdown]
# 1. dataset 준비

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# !unzip ssd.pytorch.zip

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# !mkdir data

# %%
# %cd /content/gdrive/MyDrive/data
# Out:
# /content/gdrive/MyDrive/data

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.datasets as datasets

# %%
dataset = datasets.Kitti(root = '/content/gdrive/MyDrive/data', train = True, download = True)

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 5.3 MB/s
# ...

# %%
torch.__version__
# Out:
# '1.12.1+cu113'

# %%
# !pip install torch==1.10.1+cu111 torchvision==0.11.2+cu111 torchaudio==0.10.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████▌                   | 834.1 MB 1.3 MB/s eta 0:16:44tcmalloc: large alloc 1147494400 bytes == 0x660c4000 @  0x7fc0568aa615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
#      |███████████████▉                | 1055.7 MB 1.3 MB/s eta 0:14:02tcmalloc: large alloc 1434370048 bytes == 0x38ec000 @  0x7fc0568aa615 0x592b76 0x4df71e 0x59afff 0x515655 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x598e3b 0x511f68 0x598e3b 0x511f68 0x598e3b 0x511f68 0x4bc98a 0x532e76 0x594b72 0x515600 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x5118f8 0x593dd7
# ...

# %%
# %cd /content/gdrive/MyDrive/ssd.pytorch
# !python train.py
# Out:
# /content/gdrive/MyDrive/ssd.pytorch
# /content/gdrive/MyDrive/ssd.pytorch/ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# Loading base network...
# Initializing weights...
# train.py:244: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(param)
# Loading the dataset...
# Training SSD on: Kitti
# Using the specified args:
# Namespace(basenet='resnet50.pth', batch_size=16, cuda=True, dataset='Kitti', dataset_root='/content/gdrive/MyDrive/data/Kitti/', gamma=0.1, lr=0.002, momentum=0.9, num_workers=4, resume=None, save_folder='/content/gdrive/MyDrive/ssd.pytorch/weights/', start_iter=0, visdom=False, weight_decay=0.0005)
# ...
